# %%
import os
import sys
import time

# %%
import importlib
from pathlib import Path

ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import library.uart3_protocol as uart3_protocol
import library.aes_gcm_app as aes_gcm_app
import library.ml_kem_app as ml_kem_app
importlib.reload(uart3_protocol)
importlib.reload(aes_gcm_app)
importlib.reload(ml_kem_app)

from library.uart3_protocol import UART3Protocol
from library.aes_gcm_app import STM32AESGCM
from library.ml_kem_app import STM32MLKEM

print("Library updated / reloaded")
# Out:
# Library updated / reloaded

# %%
PORT = "COM6"
BAUD = 4000000
AES_GCM_APP_MAX_SIZE = 65536
TIMEOUT = 0.01

uart = UART3Protocol(
    port = PORT,
    baud = BAUD,
    max_buffer_size = AES_GCM_APP_MAX_SIZE,
    timeout = TIMEOUT
)

uart.open()
time.sleep(0.5)

# %%
kem = STM32MLKEM(uart)
kem.clear()
# Out:
# True

# %%
try:
    result = kem.handshake()
except RuntimeError as e:
    print("KEM handshake failed:\n\t", e)
    print("Trying rekey...")
    kem.rekey()
    result = kem.handshake()

print("KEM handshake OK")
# Out:
# KEM handshake failed:
# 	 Expected 'READY', got 'KEM_NOT_READY'
# Trying rekey...
# KEM handshake OK

# %%
print("public_key len:", len(result["public_key"]))
print("kem_ciphertext len:", len(result["kem_ciphertext"]))
print("shared_secret_python len:", len(result["shared_secret_python"]))
print("aes_key:", result["aes_key"].hex())
# Out:
# public_key len: 1184
# kem_ciphertext len: 1088
# shared_secret_python len: 32
# aes_key: e7500626e97a2c9a5417ebdaa935d878aa6f9ca0e87ff8809ea31e671622250c

# %%
KEY = result["aes_key"]
aes = STM32AESGCM(uart, KEY)
# 清 Python and stm32 端 buffer
aes.clear()
# Out:
# True

# %%
def run_aes_gcm_stress_test(
    aes,
    uart,
    test_method,
    total=50,
    size=None,
    sleep_time=0.01,
    auto_resync=True,
):
    """
    test_method examples:
        aes.stm32_encrypt_stm32_decrypt_test
        aes.stm32_encrypt_local_decrypt_test
        aes.local_encrypt_stm32_decrypt_test
    """

    if size is None:
        size = uart.max_buffer_size

    ok_count = 0
    error_count = 0
    last_elapsed = 0.0

    start_all = time.perf_counter()

    method_name = getattr(test_method, "__name__", str(test_method))
    print(f"Method: {method_name}")
    print(f"Total : {total}")
    print(f"Size  : {size} bytes")
    print()

    for i in range(total):
        data = os.urandom(size)

        try:
            result = test_method(data)

            last_elapsed = result["elapsed"]

            if result["ok"]:
                ok_count += 1
            else:
                error_count += 1
                print()
                print(f"ERROR at {i + 1}/{total}")
                print("nonce:", result["nonce"].hex())
                print("tag:", result["tag"].hex())
                print("single elapsed:", result["elapsed"])

        except Exception as e:
            error_count += 1
            print()
            print(f"EXCEPTION at {i + 1}/{total}: {e}")

            if auto_resync:
                try:
                    uart.clear_buffers()
                    uart.write_line("CLEAR")
                    aes._wait_ready(timeout=2.0)
                    print("resync OK")
                except Exception as clear_error:
                    print("resync failed:", clear_error)

        done = i + 1
        percent = done / total * 100

        total_elapsed = time.perf_counter() - start_all
        avg_time = total_elapsed / done
        eta = avg_time * (total - done)

        print(
            f"Progress: {done}/{total} "
            f"({percent:6.2f}%) | "
            f"OK={ok_count} | ERR={error_count} | "
            f"last={last_elapsed:7.3f}s | "
            f"total={total_elapsed:8.2f}s | "
            f"avg={avg_time:7.3f}s | "
            f"ETA={eta:8.2f}s", # Estimated Time Arrival(預估剩餘時間)
            end="\r",
            flush=True
        )

        time.sleep(sleep_time)

    total_elapsed = time.perf_counter() - start_all

    print()
    print(f"Total time: {total_elapsed:.2f} s")
    print(f"Average time per test: {total_elapsed / total:.4f} s")

    if error_count == 0:
        print("NO ERROR")
    else:
        print(f"HAS ERROR: {error_count}")

    return {
        "method": method_name,
        "total": total,
        "size": size,
        "ok_count": ok_count,
        "error_count": error_count,
        "total_elapsed": total_elapsed,
        "avg_time": total_elapsed / total,
    }

print("build funtion: run_aes_gcm_stress_test")
# Out:
# build funtion: run_aes_gcm_stress_test

# %%
methods = [
    aes.stm32_encrypt_local_decrypt_test,
    aes.local_encrypt_stm32_decrypt_test,
    aes.stm32_encrypt_stm32_decrypt_test,
]

for method in methods:
    print("-" * 150)
    result = run_aes_gcm_stress_test(
        aes=aes,
        uart=uart,
        test_method=method,
        total=10,
        size=uart.max_buffer_size,
    )

    print(result)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Method: stm32_encrypt_local_decrypt_test
# Total : 10
# Size  : 65536 bytes
#
# Progress: 10/10 (100.00%) | OK=10 | ERR=0 | last=  0.603s | total=    6.15s | avg=  0.615s | ETA=    0.00s
# Total time: 6.16 s
# Average time per test: 0.6158 s
# NO ERROR
# {'method': 'stm32_encrypt_local_decrypt_test', 'total': 10, 'size': 65536, 'ok_count': 10, 'error_count': 0, 'total_elapsed': 6.158137874968816, 'avg_time': 0.6158137874968815}
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Method: local_encrypt_stm32_decrypt_test
# Total : 10
# Size  : 65536 bytes
#
# Progress: 10/10 (100.00%) | OK=10 | ERR=0 | last=  0.603s | total=    6.14s | avg=  0.614s | ETA=    0.00s
# Total time: 6.16 s
# Average time per test: 0.6156 s
# NO ERROR
# {'method': 'local_encrypt_stm32_decrypt_test', 'total': 10, 'size': 65536, 'ok_count': 10, 'error_count': 0, 'total_elapsed': 6.1555579580017366, 'avg_time': 0.6155557958001736}
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Method: stm32_encrypt_stm32_decrypt_test
# Total : 10
# Size  : 65536 bytes
#
# Progress: 10/10 (100.00%) | OK=10 | ERR=0 | last=  1.205s | total=   12.16s | avg=  1.216s | ETA=    0.00s
# Total time: 12.18 s
# Average time per test: 1.2175 s
# NO ERROR
# {'method': 'stm32_encrypt_stm32_decrypt_test', 'total': 10, 'size': 65536, 'ok_count': 10, 'error_count': 0, 'total_elapsed': 12.175148291978985, 'avg_time': 1.2175148291978986}

# %%
uart.close()
